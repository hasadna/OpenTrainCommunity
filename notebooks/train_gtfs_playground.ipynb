# %% [markdown]
# This is an intro / tutorial notebook for getting started with GTFS data.
#
# It is based on work that is shown on my dev blog [simplistic.me](http://simplistic.me/tag/gtfs.html). Posts there are not updated to current versions, mine or other packages'. Still, do check it out and feel free to comment or post an issue or pull request.
#
# This is only one basic workflow which I like. You can find many more examples for working with GTFS online. There are tools and packages in many languages.
#
# THE place to start is [awesome-transit](https://github.com/CUTR-at-USF/awesome-transit).
#
# TODO: Add more tools to this notebook - peartree, GTFSTK, UrbanAccess, Pandana

# %% [markdown]
# ## Installation
# TODO: Go to open-bus README (this needs to be there)
#
# 1. Install Anaconda3
# 1. Create a virtual environment (call it openbus or something indicative): `conda create -n openbus`
# 1. Clone [open-bus-explore](https://github.com/cjer/open-bus-explore) - `git clone https://github.com/cjer/open-bus-explore`
# 1. Install everything in [requirements.txt](https://github.com/cjer/open-bus-explore/blob/master/requirements.txt)
#     1. partridge, peartree and GTFSTK require `pip install`
#     1. the rest you should install using `conda install -c conda-forge <package_name>`
# 1. Run JupyterLab or Jupyter Notebook

# %% [markdown]
# ## Imports and config

# %%
# Put these at the top of every notebook, to get automatic reloading and inline plotting
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import partridge as ptg
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt
import datetime

from gtfs_utils import *

# %% [markdown]
# ## Getting the data
# Three main options:
# 1. Tap into the source: We have some functions for working with [MoT's FTP](#FTP).
# 1. Our archive on [Amazon S3](#S3-archive)
# 1. [TransitFeeds](#TransitFeeds)' Archive
#
# You can go to our redash interface if you prefer to work with SQL (can't attest to what the state of it is at any given moment).

# %% [markdown]
# ### FTP

# %%
get_ftp_dir()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-01081b0aaa7b> in <module>
# ----> 1 get_ftp_dir()
#
# NameError: name 'get_ftp_dir' is not defined

# %% [markdown]
# We have the expected file names in constant variables in `gtfs_utils`

# %%
GTFS_FILE_NAME
# Out:
# 'israel-public-transportation.zip'

# %%
TARIFF_FILE_NAME
# Out:
# 'Tariff.zip'

# %%
LOCAL_GTFS_ZIP_PATH = 'data/sample/latest_gtfs.zip' 
LOCAL_TARIFF_PATH = 'data/sample/latest_tariff.zip' 

get_ftp_file(file_name = GTFS_FILE_NAME, local_path = LOCAL_GTFS_ZIP_PATH)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-18-a459f5f32d13> in <module>()
#       2 LOCAL_TARIFF_PATH = 'data/sample/latest_tariff.zip'
#       3
# ----> 4 get_ftp_file(file_name = GTFS_FILE_NAME, local_path = LOCAL_GTFS_ZIP_PATH)
#
# C:\dev\ds\open-bus-explore\gtfs_utils.py in get_ftp_file(conn, file_name, local_path, force)
#      53
#      54     if not force and os.path.exists(local_path):
# ---> 55         raise FileExistsError(f'Local file \'{local_path}\' already exists, consider changing name for archiving purposes, or use the `force` flag')
#      56
#      57     print(f'Downloading {file_name}...')
#
# FileExistsError: Local file 'data/sample/latest_gtfs.zip' already exists, consider changing name for archiving purposes, or use the `force` flag

# %% [markdown]
# By default we don't overide local files. But we can, by adding `force=True`

# %%
get_ftp_file(file_name = GTFS_FILE_NAME, 
             local_path = LOCAL_GTFS_ZIP_PATH, 
             force=True)
# Out:
# Downloading israel-public-transportation.zip...
# Done.
# True

# %%
get_ftp_file(file_name = TARIFF_FILE_NAME, 
             local_path = LOCAL_TARIFF_PATH, 
             force=True )
# Out:
# Downloading Tariff.zip...
# Done.
# True

# %% [markdown]
# ### S3 archive
# Another option is to get the files from our archive on S3. For now it does require credentials.

# %%
#!aws s3 cp s3://s3.obus.hasadna.org.il/2018-02-01.zip data/gtfs_feeds/2018-02-01.zip

# %% [markdown]
# ### TransitFeeds
# You can always turn to the great [TransitFeeds](http://www.transitfeeds.com) archive and search for the feed you want (MoT's feed is archived every about 2 weeks over there).

# %% [markdown]
# ## Creating a `partridge` feed
# We have a util function for getting a `partridge` feed object by date.

# %%
feed = get_partridge_feed_by_date('/home/nirgilbo/Downloads/2019-02-25.zip', datetime.date.today())
type(feed)
# Out:
# partridge.gtfs.Feed

# %% [markdown]
# * *Another option would be to use `ptg.get_representative_feed()` which finds the busiest day of the gtfs file and returns a feed for that day. Not showing this here.*

# %% [markdown]
# The feed has in it all the (standard) files in the original GTFS zip, as [pandas](https://github.com/pandas-dev/pandas) DataFrames.

# %%
[x for x in dir(feed) if not x.startswith('_')]
# Out:
# ['agency',
#  'calendar',
#  'calendar_dates',
#  'fare_attributes',
#  'fare_rules',
#  'feed_info',
#  'frequencies',
#  'get',
#  'routes',
#  'shapes',
#  'stop_times',
#  'stops',
#  'transfers',
#  'trips']

# %%
feed.stops.head()
# Out:
#   stop_id stop_code             stop_name  \
# 0       1     38831  בי''ס בר לב/בן יהודה
# 1       2     38832        הרצל/צומת בילו
# 2       3     38833        הנחשול/הדייגים
# 3       4     38834        פריד/ששת הימים
# 4       6     38836   ת. מרכזית לוד/הורדה
#
#                                        stop_desc   stop_lat   stop_lon  \
# 0    רחוב:בן יהודה 76 עיר: כפר סבא רציף:   קומה:  32.183939  34.917812
# 1       רחוב:הרצל  עיר: קרית עקרון רציף:   קומה:  31.870034  34.819541
# 2  רחוב:הנחשול 30 עיר: ראשון לציון רציף:   קומה:  31.984553  34.782828
# 3      רחוב:משה פריד 9 עיר: רחובות רציף:   קומה:  31.888550  34.790904
# 4                  רחוב:  עיר: לוד רציף:   קומה:  31.956576  34.898125
#
#    location_type parent_station zone_id
# 0              0            NaN    6900
# 1              0            NaN     469
# 2              0            NaN    8300
# 3              0            NaN    8400
# 4              0            NaN    7000

# %%
feed.agency
# Out:
#    agency_id                          agency_name  \
# 0          2                           רכבת ישראל
# 1          3                                  אגד
# 2          4                           אגד תעבורה
# 3          5                                   דן
# 4          6                                ש.א.מ
# 5          7                       נסיעות ותיירות
# 6          8                           גי.בי.טורס
# 7         14                          נתיב אקספרס
# 8         15                            מטרופולין
# 9         16                              סופרבוס
# 10        18                                קווים
# 11        20                               כרמלית
# 12        21                              סיטי פס
# 13        23                                 גלים
# 14        24                    מועצה אזורית גולן
# 15        25                               אפיקים
# 16        30                              דן צפון
# 17        31                             דן בדרום
# 18        32                           דן באר שבע
# 19        42                 ירושלים-רמאללה איחוד
# 20        44          ירושלים-אבו-תור-ענאתא איחוד
# 21        45                 ירושלים-אלווסט איחוד
# 22        47                    ירושלים-הר הזיתים
# 23        49  ירושלים - עיסאוויה מחנה שעפאט איחוד
# 24        50                   ירושלים-דרום איחוד
# 25        51               ירושלים-צור באהר איחוד
#
#                                    agency_url agency_timezone agency_lang  \
# 0                       http://www.rail.co.il  Asia/Jerusalem          he
# 1                      http://www.egged.co.il  Asia/Jerusalem          he
# 2              http://www.egged-taavura.co.il  Asia/Jerusalem          he
# 3                        http://www.dan.co.il  Asia/Jerusalem          he
# 4                http://www.nazareth-unbs.com  Asia/Jerusalem          he
# 5                    http://www.ntt-buses.com  Asia/Jerusalem          he
# 6                     http://www.gb-tours.com  Asia/Jerusalem          he
# 7                http://www.nateevexpress.com  Asia/Jerusalem          he
# 8                  http://www.metropoline.com  Asia/Jerusalem          he
# 9                   http://www.superbus.co.il  Asia/Jerusalem          he
# 10                   http://www.kavim-t.co.il  Asia/Jerusalem          he
# 11             http://www.carmelithaifa.co.il  Asia/Jerusalem          he
# 12                  http://www.citypass.co.il  Asia/Jerusalem          he
# 13                   http://www.galeem.co.il/  Asia/Jerusalem          he
# 14                  https://www.golan.org.il/  Asia/Jerusalem          he
# 15                 http://www.afikim-t.co.il/  Asia/Jerusalem          he
# 16  http://www.haifahaifa.co.il/archives/5622  Asia/Jerusalem          he
# 17               http://www.danbadarom.co.il/  Asia/Jerusalem          he
# 18                   http://www.danbr7.co.il/  Asia/Jerusalem          he
# 19                 http://www.callkav.gov.il/  Asia/Jerusalem          he
# 20                 http://www.callkav.gov.il/  Asia/Jerusalem          he
# 21                 http://www.callkav.gov.il/  Asia/Jerusalem          he
# 22                 http://www.callkav.gov.il/  Asia/Jerusalem          he
# 23                 http://www.callkav.gov.il/  Asia/Jerusalem          he
# 24                 http://www.callkav.gov.il/  Asia/Jerusalem          he
# 25                 http://www.callkav.gov.il/  Asia/Jerusalem          he
#
#    agency_phone agency_fare_url
# 0           NaN             NaN
# 1           NaN             NaN
# 2           NaN             NaN
# 3           NaN             NaN
# 4           NaN             NaN
# 5           NaN             NaN
# 6           NaN             NaN
# 7           NaN             NaN
# 8           NaN             NaN
# 9           NaN             NaN
# 10          NaN             NaN
# 11          NaN             NaN
# 12          NaN             NaN
# 13          NaN             NaN
# 14          NaN             NaN
# 15          NaN             NaN
# 16          NaN             NaN
# 17          NaN             NaN
# 18          NaN             NaN
# 19          NaN             NaN
# 20          NaN             NaN
# 21          NaN             NaN
# 22          NaN             NaN
# 23          NaN             NaN
# 24          NaN             NaN
# 25          NaN             NaN

# %%
feed.routes.head()
# Out:
#   route_id agency_id route_short_name  \
# 0        1        25                1
# 1        2        25                1
# 2        3        25                2
# 3        5        25                2
# 4        7        25                3
#
#                                      route_long_name route_desc  route_type  \
# 0  ת. רכבת יבנה מערב-יבנה<->ת. רכבת יבנה מזרח-יבנ...  67001-1-#           3
# 1  ת. רכבת יבנה מזרח-יבנה<->ת. רכבת יבנה מערב-יבנ...  67001-2-#           3
# 2  ת. רכבת יבנה מערב-יבנה<->ת. רכבת יבנה מזרח-יבנ...  56002-1-#           3
# 3  ת. רכבת יבנה מזרח-יבנה<->ת. רכבת יבנה מערב-יבנ...  56002-2-#           3
# 4  ת. רכבת יבנה מערב-יבנה<->ת. רכבת יבנה מזרח-יבנ...  49003-1-#           3
#
#   route_color
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
rf = feed.routes
rf[rf['agency_id']=='2']
# Out:
#      route_id agency_id route_short_name  \
# 5907    20079         2               26
# 5913    20114         2               20
# 6129    20958         2               50
# 6130    20959         2               35
# 6131    20961         2               34
# 6132    20962         2               90
# 6133    20965         2               90
# 6134    20974         2               34
# 6135    20976         2               34
# 6142    21053         2              122
# 6143    21054         2              122
# 6144    21056         2              124
# 6227    21414         2               87
# 6228    21415         2               18
# 6295    22103         2              118
# 6310    22303         2               21
# 6311    22304         2               72
# 6312    22305         2               72
# 6313    22307         2              123
# 6314    22309         2              123
# 6315    22310         2               30
# 6316    22317         2              118
# 6317    22319         2               60
# 6318    22321         2               60
# 6319    22322         2               60
# 6320    22329         2               21
# 6323    22397         2               55
# 6324    22398         2               55
# 6325    22399         2               55
# 6326    22400         2               55
# ...       ...       ...              ...
# 6538    23841         2               41
# 6539    23842         2               55
# 6540    23843         2               55
# 6541    23845         2               55
# 6542    23846         2               41
# 6543    23847         2              147
# 6546    23855         2               10
# 6559    23930         2               85
# 6560    23931         2               85
# 6561    23932         2               85
# 6562    23937         2               21
# 6563    23938         2               21
# 6610    25257         2               55
# 6611    25258         2               55
# 6612    25259         2               20
# 6613    25260         2               22
# 6615    25265         2              125
# 6628    25310         2               72
# 6629    25311         2               41
# 6630    25312         2              139
# 6631    25313         2               41
# 6632    25314         2               41
# 6633    25315         2              140
# 6634    25316         2              142
# 6635    25317         2               41
# 6636    25318         2               41
# 6637    25319         2              140
# 6638    25320         2               20
# 6643    25331         2              155
# 6644    25332         2              156
#
#                                         route_long_name  route_desc  \
# 5907  תל אביב ההגנה-תל אביב יפו<->בנימינה-בנימינה גב...  29026-2-17
# 5913    תל אביב מרכז-תל אביב יפו<->באר שבע מרכז-באר שבע  32020-1-26
# 6129      מודיעין מרכז-מודיעין מכבים רעות<->נהריה-נהריה  26050-2-28
# 6130   מודיעין מרכז-מודיעין מכבים רעות<->חיפה מרכז-חיפה  27035-2-11
# 6131                     חיפה מרכז-חיפה<->רחובות-רחובות  24034-1-16
# 6132           רחובות-רחובות<->בנימינה-בנימינה גבעת עדה  34090-2-19
# 6133           בנימינה-בנימינה גבעת עדה<->רחובות-רחובות  34090-1-17
# 6134                     רחובות-רחובות<->חיפה מרכז-חיפה  24034-2-10
# 6135                     רחובות-רחובות<->חיפה מרכז-חיפה  24034-2-11
# 6142                     חוף הכרמל-חיפה<->כרמיאל-כרמיאל   14122-2-1
# 6143                     כרמיאל-כרמיאל<->חוף הכרמל-חיפה   14122-1-1
# 6144             בית שמש-בית שמש<->ירושלים מלחה-ירושלים   15124-1-2
# 6227                          בית שמש-בית שמש<->לוד-לוד   47087-2-2
# 6228                          לוד-לוד<->בית שמש-בית שמש   46018-1-2
# 6295                      לוד-לוד<->ראשונים-ראשון לציון   13118-1-4
# 6310            נהריה-נהריה<->תל אביב ההגנה-תל אביב יפו  46021-1-63
# 6311           בנימינה-בנימינה גבעת עדה<->אשקלון-אשקלון  30072-1-29
# 6312           בנימינה-בנימינה גבעת עדה<->אשקלון-אשקלון  30072-1-30
# 6313               כרמיאל-כרמיאל<->באר שבע מרכז-באר שבע   15123-1-6
# 6314               באר שבע מרכז-באר שבע<->כרמיאל-כרמיאל   15123-2-5
# 6315              באר שבע מרכז-באר שבע<->חיפה מרכז-חיפה  31030-2-34
# 6316                      ראשונים-ראשון לציון<->לוד-לוד   13118-2-5
# 6317                        נתניה-נתניה<->אשקלון-אשקלון   27060-1-6
# 6318                        נתניה-נתניה<->אשקלון-אשקלון   27060-1-7
# 6319                        נתניה-נתניה<->אשקלון-אשקלון   27060-1-8
# 6320             נהריה-נהריה<->תל אביב מרכז-תל אביב יפו  46021-1-64
# 6323            נהריה-נהריה<->נת-בג-נמל תעופה בן גוריון  33055-1-20
# 6324            נת-בג-נמל תעופה בן גוריון<->נהריה-נהריה  33055-2-23
# 6325            נת-בג-נמל תעופה בן גוריון<->נהריה-נהריה  33055-2-24
# 6326            נת-בג-נמל תעופה בן גוריון<->נהריה-נהריה  33055-2-25
# ...                                                 ...         ...
# 6538               הרצליה-הרצליה<->באר שבע מרכז-באר שבע  24041-1-21
# 6539            נהריה-נהריה<->נת-בג-נמל תעופה בן גוריון  33055-1-34
# 6540            נת-בג-נמל תעופה בן גוריון<->נהריה-נהריה  33055-2-38
# 6541            נת-בג-נמל תעופה בן גוריון<->נהריה-נהריה  33055-2-39
# 6542           רעננה מערב-הרצליה<->באר שבע מרכז-באר שבע  24041-1-22
# 6543  ירושלים - יצחק נבון-ירושלים<->נת-בג-נמל תעופה ...   19147-2-2
# 6546    ירושלים מלחה-ירושלים<->תל אביב מרכז-תל אביב יפו  43010-2-15
# 6559                   בית שאן-בית שאן<->חיפה מרכז-חיפה  44085-1-28
# 6560                   בית שאן-בית שאן<->חיפה מרכז-חיפה  44085-1-29
# 6561                   חיפה מרכז-חיפה<->בית שאן-בית שאן  44085-2-27
# 6562            נהריה-נהריה<->תל אביב ההגנה-תל אביב יפו  46021-1-95
# 6563            תל אביב ההגנה-תל אביב יפו<->נהריה-נהריה  46021-2-76
# 6610            נהריה-נהריה<->נת-בג-נמל תעופה בן גוריון  33055-1-36
# 6611            נהריה-נהריה<->נת-בג-נמל תעופה בן גוריון  33055-1-37
# 6612   תל אביב ההגנה-תל אביב יפו<->באר שבע מרכז-באר שבע  32020-1-70
# 6613          תל אביב ההגנה-תל אביב יפו<->אשקלון-אשקלון  36022-1-33
# 6615       רעננה מערב-הרצליה<->תל אביב מרכז-תל אביב יפו   18125-1-4
# 6628           בנימינה-בנימינה גבעת עדה<->אשקלון-אשקלון  30072-1-44
# 6629           באר שבע מרכז-באר שבע<->רעננה מערב-הרצליה  24041-2-24
# 6630    רשל''צ משה דיין-ראשון לציון<->רעננה מערב-הרצליה   21139-2-3
# 6631           באר שבע מרכז-באר שבע<->רעננה מערב-הרצליה  24041-2-25
# 6632           באר שבע מרכז-באר שבע<->רעננה מערב-הרצליה  24041-2-26
# 6633                  נתיבות-נתיבות<->רעננה מערב-הרצליה   22140-2-3
# 6634                  אשקלון-אשקלון<->רעננה מערב-הרצליה   22142-2-5
# 6635           באר שבע מרכז-באר שבע<->רעננה מערב-הרצליה  24041-2-27
# 6636           באר שבע מרכז-באר שבע<->רעננה מערב-הרצליה  24041-2-28
# 6637                  רעננה מערב-הרצליה<->נתיבות-נתיבות   22140-1-2
# 6638   באר שבע מרכז-באר שבע<->תל אביב ההגנה-תל אביב יפו  32020-2-55
# 6643                 תל אביב מרכז-תל אביב יפו<->עכו-עכו   15155-2-1
# 6644                            אשקלון-אשקלון<->עכו-עכו   17156-2-1
#
#       route_type route_color
# 5907           2         NaN
# 5913           2         NaN
# 6129           2         NaN
# 6130           2         NaN
# 6131           2         NaN
# 6132           2         NaN
# 6133           2         NaN
# 6134           2         NaN
# 6135           2         NaN
# 6142           2         NaN
# 6143           2         NaN
# 6144           2         NaN
# 6227           2         NaN
# 6228           2         NaN
# 6295           2         NaN
# 6310           2         NaN
# 6311           2         NaN
# 6312           2         NaN
# 6313           2         NaN
# 6314           2         NaN
# 6315           2         NaN
# 6316           2         NaN
# 6317           2         NaN
# 6318           2         NaN
# 6319           2         NaN
# 6320           2         NaN
# 6323           2         NaN
# 6324           2         NaN
# 6325           2         NaN
# 6326           2         NaN
# ...          ...         ...
# 6538           2         NaN
# 6539           2         NaN
# 6540           2         NaN
# 6541           2         NaN
# 6542           2         NaN
# 6543           2         NaN
# 6546           2         NaN
# 6559           2         NaN
# 6560           2         NaN
# 6561           2         NaN
# 6562           2         NaN
# 6563           2         NaN
# 6610           2         NaN
# 6611           2         NaN
# 6612           2         NaN
# 6613           2         NaN
# 6615           2         NaN
# 6628           2         NaN
# 6629           2         NaN
# 6630           2         NaN
# 6631           2         NaN
# 6632           2         NaN
# 6633           2         NaN
# 6634           2         NaN
# 6635           2         NaN
# 6636           2         NaN
# 6637           2         NaN
# 6638           2         NaN
# 6643           2         NaN
# 6644           2         NaN
#
# [125 rows x 7 columns]

# %%
feed.calendar.head()
# Out:
#   service_id  sunday  monday  tuesday  wednesday  thursday  friday  saturday  \
# 0          1       1       1        1          1         1       0         0
# 1          9       1       1        1          1         1       0         0
# 2         17       1       1        1          1         1       0         0
# 3         23       1       1        1          1         1       0         0
# 4         29       1       1        1          1         1       0         0
#
#    start_date    end_date
# 0  2019-02-24  2019-03-19
# 1  2019-02-24  2019-03-19
# 2  2019-02-24  2019-03-19
# 3  2019-02-24  2019-03-19
# 4  2019-02-24  2019-04-25

# %%
feed.trips.head()
# Out:
#   route_id service_id          trip_id  trip_headsign  direction_id shape_id
# 0        1          1  30900053_240219  רכבת מזרח/שוק             0    97105
# 1        1          1  30900054_240219  רכבת מזרח/שוק             0    97105
# 2        1          1  30900055_240219  רכבת מזרח/שוק             0    97105
# 3        1          1  30900056_240219  רכבת מזרח/שוק             0    97105
# 4        1          1  30900057_240219  רכבת מזרח/שוק             0    97105

# %%
feed.stop_times.head()
# Out:
#            trip_id  arrival_time  departure_time stop_id  stop_sequence  \
# 0  10096398_240219       75600.0         75600.0   34657              1
# 1  10096398_240219       75640.0         75640.0   35317              2
# 2  10096398_240219       75716.0         75716.0   34436              3
# 3  10096398_240219       75858.0         75858.0   34444              4
# 4  10096398_240219       76483.0         76483.0   35506              5
#
#    pickup_type drop_off_type  shape_dist_traveled
# 0            0             1                    0
# 1            0             0                  276
# 2            0             0                  857
# 3            0             0                 1955
# 4            0             0                14838

# %%
stops = feed.stops
stop_times = feed.stop_times.merge(stops, on='stop_id')

# %%
m = stop_times.merge(feed.trips, on="trip_id")

# %%
n = m.merge(feed.routes, on="route_id")

# %%
o = n[n['agency_id']=='2']

# %%
p = o.merge(feed.calendar, on="service_id")

# %%
stop_ids = p['stop_id'].unique()

# %%
feed.stops[feed.stops.stop_id.isin(stop_ids)]
# Out:
#       stop_id stop_code               stop_name  \
# 23826   37290     17106                   שדרות
# 23827   37292     17104           תל אביב ההגנה
# 23828   37294     17102         רשל''צ משה דיין
# 23829   37296     17100               הוד השרון
# 23830   37298     17098                 ראשונים
# 23831   37300     17096               יבנה מערב
# 23832   37302     17094           ראש העין-צפון
# 23833   37304     17092                 כפר סבא
# 23834   37306     17090                   נת-בג
# 23835   37308     17088               להבים רהט
# 23836   37310     17086                  דימונה
# 23837   37312     17084            באר שבע מרכז
# 23838   37314     17082            באר שבע-צפון
# 23839   37316     17080                 קרית גת
# 23840   37318     17078            ירושלים מלחה
# 23841   37320     17076         ירושלים גן חיות
# 23842   37322     17074                 בית שמש
# 23843   37324     17072                  אשקלון
# 23844   37326     17070           אשדוד עד הלום
# 23845   37328     17068               יבנה מזרח
# 23846   37330     17066                באר יעקב
# 23847   37332     17064                  רחובות
# 23848   37334     17062            לוד-גני אביב
# 23849   37336     17060                    רמלה
# 23850   37338     17058                     לוד
# 23851   37340     17056                 כפר חבד
# 23852   37342     17054           בת ים קוממיות
# 23853   37344     17052            בת ים יוספטל
# 23854   37346     17050           חולון וולפסון
# 23855   37348     17048              צומת חולון
# ...       ...       ...                     ...
# 23864   37366     17030                   נתניה
# 23865   37368     17028               חדרה מערב
# 23866   37370     17026         קיסריה פרדס חנה
# 23867   37372     17024                 בנימינה
# 23868   37374     17022                   עתלית
# 23869   37376     17020               חוף הכרמל
# 23870   37378     17018                 בת גלים
# 23871   37380     17016               חיפה מרכז
# 23872   37382     17014                   נהריה
# 23873   37384     17012                     עכו
# 23874   37386     17010              חוצות מפרץ
# 23875   37388     17008  מרכזית המפרץ - קו החוף
# 23876   37392     17004               קרית חיים
# 23877   37394     17002            מודיעין מרכז
# 23878   37396     17000            פאתי מודיעין
# 24530   38643     17108                  נתיבות
# 25016   39260     17109                  אופקים
# 26056   40581     17113                כפר ברוך
# 26057   40582     17112                   עפולה
# 26058   40583     17111                 בית שאן
# 26059   40584     17110               כפר יהושע
# 26088   40640     17114        נתניה קריית ספיר
# 26566   41291     17116                  אחיהוד
# 26567   41292     17115                  כרמיאל
# 26568   41293     17117             קרית מוצקין
# 27295   42286     17118     ירושלים - יצחק נבון
# 27335   42416     17122              רעננה דרום
# 27336   42417     17121              רעננה מערב
# 27337   42419     17119              קרית מלאכי
# 27408   42507     17123            מרכזית המפרץ
#
#                                                stop_desc   stop_lat  \
# 23826  רחוב:מסילת ברזל  עיר: שער הנגב רציף:   קומה:  ...  31.515877
# 23827  רחוב:מסילת ברזל  עיר: תל אביב יפו רציף:   קומה...  32.053978
# 23828  רחוב:מסילת ברזל  עיר: ראשון לציון רציף:   קומה...  31.987987
# 23829  רחוב:מסילת ברזל  עיר: הוד השרון רציף:   קומה: ...  32.170213
# 23830  רחוב:מסילת ברזל  עיר: ראשון לציון רציף:   קומה...  31.948927
# 23831  רחוב:מסילת ברזל  עיר: יבנה רציף:   קומה:   תחנ...  31.891676
# 23832  רחוב:מסילת ברזל  עיר: ראש העין רציף:   קומה:  ...  32.120865
# 23833  רחוב:מסילת ברזל  עיר: הוד השרון רציף:   קומה: ...  32.167369
# 23834  רחוב:מסילת ברזל  עיר: נמל תעופה בן גוריון רציף...  32.000360
# 23835  רחוב:מסילת ברזל  עיר: להבים רציף:   קומה:   תח...  31.369907
# 23836  רחוב:מסילת ברזל  עיר: דימונה רציף:   קומה:   ת...  31.068597
# 23837  רחוב:מסילת ברזל  עיר: באר שבע רציף:   קומה:   ...  31.242886
# 23838  רחוב:מסילת ברזל  עיר: באר שבע רציף:   קומה:   ...  31.262089
# 23839  רחוב:מסילת ברזל  עיר: קרית גת רציף:   קומה:   ...  31.603526
# 23840  רחוב:מסילת ברזל  עיר: ירושלים רציף:   קומה:   ...  31.747801
# 23841  רחוב:מסילת ברזל  עיר: ירושלים רציף:   קומה:   ...  31.744791
# 23842  רחוב:מסילת ברזל  עיר: בית שמש רציף:   קומה:   ...  31.757821
# 23843  רחוב:מסילת ברזל  עיר: אשקלון רציף:   קומה:   ת...  31.676856
# 23844  רחוב:מסילת ברזל  עיר: אשדוד רציף:   קומה:   תח...  31.774061
# 23845  רחוב:מסילת ברזל  עיר: יבנה רציף:   קומה:   תחנ...  31.861702
# 23846  רחוב:מסילת ברזל  עיר: באר יעקב רציף:   קומה:  ...  31.932781
# 23847  רחוב:מסילת ברזל  עיר: רחובות רציף:   קומה:   ת...  31.908691
# 23848  רחוב:מסילת ברזל  עיר: עמק לוד רציף:   קומה:   ...  31.966977
# 23849  רחוב:מסילת ברזל  עיר: רמלה רציף:   קומה:   תחנ...  31.928809
# 23850  רחוב:מסילת ברזל  עיר: לוד רציף:   קומה:   תחנת...  31.945234
# 23851  רחוב:מסילת ברזל  עיר: כפר חב''ד רציף:   קומה: ...  31.993188
# 23852  רחוב:מסילת ברזל  עיר: חולון רציף:   קומה:   תח...  32.000989
# 23853  רחוב:מסילת ברזל  עיר: בת ים רציף:   קומה:   תח...  32.014588
# 23854  רחוב:מסילת ברזל  עיר: תל אביב יפו רציף:   קומה...  32.035462
# 23855  רחוב:מסילת ברזל  עיר: תל אביב יפו רציף:   קומה...  32.037036
# ...                                                  ...        ...
# 23864  רחוב:מסילת ברזל  עיר: נתניה רציף:   קומה:   תח...  32.319915
# 23865  רחוב:מסילת ברזל  עיר: חדרה רציף:   קומה:   תחנ...  32.438199
# 23866  רחוב:מסילת ברזל  עיר: פרדס חנה כרכור רציף:   ק...  32.485187
# 23867  רחוב:מסילת ברזל  עיר: בנימינה גבעת עדה רציף:  ...  32.514386
# 23868  רחוב:מסילת ברזל  עיר: עתלית רציף:   קומה:   תח...  32.692924
# 23869  רחוב:מסילת ברזל  עיר: חיפה רציף:   קומה:   תחנ...  32.793600
# 23870  רחוב:מסילת ברזל  עיר: חיפה רציף:   קומה:   תחנ...  32.830498
# 23871  רחוב:מסילת ברזל  עיר: חיפה רציף:   קומה:   תחנ...  32.822306
# 23872  רחוב:מסילת ברזל  עיר: נהריה רציף:   קומה:   תח...  33.005075
# 23873  רחוב:מסילת ברזל  עיר: עכו רציף:   קומה:   תחנת...  32.928339
# 23874  רחוב:מסילת ברזל  עיר: חיפה רציף:   קומה:   תחנ...  32.809527
# 23875  רחוב:מסילת ברזל  עיר: חיפה רציף:   קומה:   תחנ...  32.793921
# 23876  רחוב:מסילת ברזל  עיר: חיפה רציף:   קומה:   תחנ...  32.824918
# 23877  רחוב:מסילת ברזל  עיר: מודיעין מכבים רעות רציף:...  31.901238
# 23878  רחוב:מסילת ברזל  עיר: מודיעין מכבים רעות רציף:...  31.893133
# 24530  רחוב:מסילת ברזל  עיר: נתיבות רציף:   קומה:   ת...  31.410871
# 25016  רחוב:מסילת ברזל  עיר: אופקים רציף:   קומה:   ת...  31.322628
# 26056  רחוב:מסילת ברזל  עיר: עמק יזרעאל רציף:   קומה:...  32.647554
# 26057  רחוב:מסילת ברזל  עיר: עמק יזרעאל רציף:   קומה:...  32.622003
# 26058  רחוב:מסילת ברזל  עיר: בית שאן רציף:   קומה:   ...  32.514683
# 26059  רחוב:מסילת ברזל  עיר: עמק יזרעאל רציף:   קומה:...  32.681069
# 26088  רחוב:מסילת ברזל  עיר: נתניה רציף:   קומה:   תח...  32.278832
# 26566  רחוב:מסילת ברזל  עיר: משגב רציף:   קומה:   תחנ...  32.911590
# 26567  רחוב:מסילת ברזל  עיר: כרמיאל רציף:   קומה:   ת...  32.924764
# 26568  רחוב:מסילת ברזל  עיר: קרית מוצקין רציף:   קומה...  32.833133
# 27295  רחוב:מסילת ברזל  עיר: ירושלים רציף:   קומה:   ...  31.788062
# 27335  רחוב:מסילת ברזל  עיר: רעננה רציף:   קומה:   תח...  32.172568
# 27336  רחוב:מסילת ברזל  עיר: הרצליה רציף:   קומה:   ת...  32.180006
# 27337  רחוב:מסילת ברזל  עיר: יואב רציף:   קומה:   תחנ...  31.747335
# 27408  רחוב:מסילת ברזל  עיר: חיפה רציף:   קומה:   תחנ...  32.792942
#
#         stop_lon  location_type parent_station zone_id
# 23826  34.586059              0            NaN    1926
# 23827  34.784839              0            NaN    5000
# 23828  34.757392              0            NaN    8300
# 23829  34.901609              0            NaN    9700
# 23830  34.802622              0            NaN    8300
# 23831  34.731526              0            NaN   14067
# 23832  34.934527              0            NaN    2640
# 23833  34.917428              0            NaN    9700
# 23834  34.870481              0            NaN    1748
# 23835  34.798040              0            NaN    1271
# 23836  35.011710              0            NaN    2200
# 23837  34.798546              0            NaN    9000
# 23838  34.809287              0            NaN    9000
# 23839  34.777955              0            NaN    2630
# 23840  35.188216              0            NaN    3000
# 23841  35.178044              0            NaN    3000
# 23842  34.989515              0            NaN    2610
# 23843  34.604447              0            NaN    7100
# 23844  34.666059              0            NaN      70
# 23845  34.744295              0            NaN   14066
# 23846  34.828591              0            NaN    2530
# 23847  34.806351              0            NaN    8400
# 23848  34.878790              0            NaN    1893
# 23849  34.877304              0            NaN    8500
# 23850  34.875081              0            NaN    7000
# 23851  34.853030              0            NaN     696
# 23852  34.759437              0            NaN    6600
# 23853  34.762082              0            NaN    6200
# 23854  34.759782              0            NaN    5000
# 23855  34.776461              0            NaN    5000
# ...          ...            ...            ...     ...
# 23864  34.869257              0            NaN    7400
# 23865  34.899321              0            NaN    6500
# 23866  34.954099              0            NaN    7800
# 23867  34.949573              0            NaN    9800
# 23868  34.940314              0            NaN      53
# 23869  34.957404              0            NaN    4000
# 23870  34.981888              0            NaN    4000
# 23871  34.997177              0            NaN    4000
# 23872  35.098710              0            NaN    9100
# 23873  35.082984              0            NaN    7600
# 23874  35.054514              0            NaN    4000
# 23875  35.037079              0            NaN    4000
# 23876  35.064290              0            NaN    4000
# 23877  35.005712              0            NaN    1200
# 23878  34.960682              0            NaN    1200
# 24530  34.571423              0            NaN     246
# 25016  34.634078              0            NaN      31
# 26056  35.207967              0            NaN    1840
# 26057  35.294721              0            NaN    1840
# 26058  35.488106              0            NaN    9200
# 26059  35.124624              0            NaN    1840
# 26088  34.865175              0            NaN    7400
# 26566  35.174068              0            NaN    1841
# 26567  35.294801              0            NaN    1139
# 26568  35.070030              0            NaN    8200
# 27295  35.202545              0            NaN    3000
# 27335  34.886294              0            NaN    8700
# 27336  34.850737              0            NaN    6400
# 27337  34.822479              0            NaN    1913
# 27408  35.032964              0            NaN    4000
#
# [68 rows x 9 columns]

# %% [markdown]
# Figuring out geographical zones requires using another zip file on MoT's FTP, using `get_zones_df()`. Which returns a simple mapping `stop_code` -> (Hebrew) `zone_name` in a DataFrame as well.

# %%
zones = get_zones_df(LOCAL_TARIFF_PATH)
zones.head()
# Out:
#   stop_code     zone_name
# 0      2716  סובב ירושלים
# 1      2718  סובב ירושלים
# 2      2720  סובב ירושלים
# 3      2721  סובב ירושלים
# 4      2747  סובב ירושלים

# %% [markdown]
# ## Tidy DataFrame
# A (monstrous) merged DataFrame for fancy analysis can be got using `get_tidy_feed_df()`, whom you pass a partridge feed and extra dataframes you want to merge to it (only `zones` is used here).
#
# This takes a few minutes (MoT's GTFS is big)

# %%
f = get_tidy_feed_df(feed, [zones])

# %% [markdown]
# and what you get is this:

# %%
f.head()
# Out:
#            trip_id departure_time arrival_time stop_id  stop_sequence  \
# 0  32184517_040618       21:36:00     21:36:00   37318              1
# 1  32184517_040618       22:19:00     22:19:00   37322              2
# 2  32184517_040618       22:41:00     22:41:00   37336              3
# 3  32184517_040618       22:45:00     22:45:00   37338              4
# 4  32184517_040618       22:51:00     22:51:00   37334              5
#
#       stop_name   stop_lat   stop_lon stop_code route_id direction_id  \
# 0  ירושלים מלחה  31.747801  35.188216     17078    22786            1
# 1       בית שמש  31.757821  34.989515     17074    22786            1
# 2          רמלה  31.928809  34.877304     17060    22786            1
# 3           לוד  31.945234  34.875081     17058    22786            1
# 4  לוד-גני אביב  31.966977  34.878790     17062    22786            1
#
#   route_short_name                                  route_long_name agency_id  \
# 0              NaN  ירושלים מלחה-ירושלים<->תל אביב מרכז-תל אביב יפו         2
# 1              NaN  ירושלים מלחה-ירושלים<->תל אביב מרכז-תל אביב יפו         2
# 2              NaN  ירושלים מלחה-ירושלים<->תל אביב מרכז-תל אביב יפו         2
# 3              NaN  ירושלים מלחה-ירושלים<->תל אביב מרכז-תל אביב יפו         2
# 4              NaN  ירושלים מלחה-ירושלים<->תל אביב מרכז-תל אביב יפו         2
#
#   agency_name     zone_name
# 0  רכבת ישראל  סובב ירושלים
# 1  רכבת ישראל  אזור בית שמש
# 2  רכבת ישראל        גוש דן
# 3  רכבת ישראל        גוש דן
# 4  רכבת ישראל        גוש דן

# %% [markdown]
# In the future I intend to make this more customizable (field selection, transformations and more).

# %%
f.shape
# Out:
# (3151606, 16)

# %%
feed.stop_times.shape
# Out:
# (3151606, 8)

# %% [markdown]
# So we truly have all the stop times for one whole day of trips.

# %% [markdown]
# ## Random examples

# %%
f.set_index('arrival_time').resample('10T').size().plot()

# %%
zone_counts = (f.set_index('arrival_time')
               .groupby([pd.Grouper(freq='10T'), 'zone_name'])
               .size().reset_index()
               .rename(columns={0: 'trips'})
               .assign(time = lambda x: pd.DatetimeIndex(x.arrival_time+datetime.date.today()))
              )

# %%
lines = alt.Chart(zone_counts).mark_line().encode(
    x = alt.X('time:T', axis=alt.Axis(format='%H:%M')),
    y = 'trips',
    color = alt.Color('zone_name', legend=None),
    tooltip = 'zone_name'
).interactive()

annotation = alt.Chart(zone_counts).mark_text(
    align='left',
    baseline='middle',
    fontSize = 12,
    dx = 4
).encode(
    x='time:T',
    y='trips',
    text='zone_name'
).transform_filter(
    ((alt.datum.trips==8785) | (alt.datum.trips == 5347) | (alt.datum.trips == 1985)) 
)

(lines + annotation).properties(height=400, width=600)
# Out:
# <div class="vega-embed" id="c376271e-5cd9-4628-8904-22bdfd92cde5"></div>
#
# <style>
# .vega-embed .vega-actions > a {
#     transition: opacity 200ms ease-in;
#     opacity: 0.3;
#     margin-right: 0.6em;
#     color: #444;
#     text-decoration: none;
# }
#
# .vega-embed .vega-actions > a:hover {
#     color: #000;
#     text-decoration: underline;
# }
#
# .vega-embed:hover .vega-actions > a {
#     opacity: 1;
#     transition: 0s;
# }
#
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 1.2em;
# }
# </style>
